# %%
import os
import pandas as pd
import numpy as np
import json

# %%
metadata = pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\1538011337.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv("movies_metadata.csv")

# %%
metadata.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
columnList = metadata.columns

# %%
columnList
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
metadata.shape
# Out:
# (45466, 24)

# %%
for i in ['adult', 'belongs_to_collection', 'budget','homepage', 'imdb_id','popularity', 'poster_path', 'production_companies',
       'production_countries', 'release_date', 'revenue','spoken_languages', 'status', 'tagline', 'original_title','video',
       'vote_average', 'vote_count']:
    if i in columnList:
        metadata = metadata.drop(i, axis =1)

# %%
metadata.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
reSequence = ['id','title','genres','original_language','overview','runtime']

# %%
metadata = metadata.reindex(columns = reSequence)

# %%
metadata.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                               genres original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                     [{'id': 35, 'name': 'Comedy'}]                en
#
#                                             overview  runtime
# 0  Led by Woody, Andy's toys live happily in his ...     81.0
# 1  When siblings Judy and Peter discover an encha...    104.0
# 2  A family wedding reignites the ancient feud be...    101.0
# 3  Cheated on, mistreated and stepped on, the wom...    127.0
# 4  Just when George Banks has recovered from his ...    106.0

# %%
metadata.shape
# Out:
# (45466, 6)

# %%
metadata.to_csv("metadata.csv", index=False)

# %% [markdown]
# #Checking Null Values

# %%
metadata.isna().sum()
# Out:
# id                     0
# title                  6
# genres                 0
# original_language     11
# overview             954
# runtime              263
# dtype: int64

# %%
metadata = metadata.dropna()

# %%
metadata.isna().sum()
# Out:
# id                   0
# title                0
# genres               0
# original_language    0
# overview             0
# runtime              0
# dtype: int64

# %%
metadata.shape
# Out:
# (44496, 6)

# %%
creds = pd.read_csv("creds.csv")

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44496 entries, 0 to 45465
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 44496 non-null  object
#  1   title              44496 non-null  object
#  2   genres             44496 non-null  object
#  3   original_language  44496 non-null  object
#  4   overview           44496 non-null  object
#  5   runtime            44496 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 2.4+ MB

# %%
metadata['id'] = metadata['id'].astype('int64')

# %%
metadata
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                   genres original_language  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                         [{'id': 35, 'name': 'Comedy'}]                en
# ...                                                  ...               ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...                fa
# 45462                      [{'id': 18, 'name': 'Drama'}]                tl
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...                en
# 45464                                                 []                en
# 45465                                                 []                en
#
#                                                 overview  runtime
# 0      Led by Woody, Andy's toys live happily in his ...     81.0
# 1      When siblings Judy and Peter discover an encha...    104.0
# 2      A family wedding reignites the ancient feud be...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...    127.0
# 4      Just when George Banks has recovered from his ...    106.0
# ...                                                  ...      ...
# 45461        Rising and falling between a man and woman.     90.0
# 45462  An artist struggles to finish his work while a...    360.0
# 45463  When one of her hits goes wrong, a professiona...     90.0
# 45464  In a small town live two brothers, one a minis...     87.0
# 45465  50 years after decriminalisation of homosexual...     75.0
#
# [44496 rows x 6 columns]

# %%
result = pd.merge(metadata, creds, on = 'id')

# %%
result.shape
# Out:
# (44571, 8)

# %%
result.isna().sum()
# Out:
# id                   0
# title                0
# genres               0
# original_language    0
# overview             0
# runtime              0
# Unnamed: 0           0
# crew                 0
# dtype: int64

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44571 entries, 0 to 44570
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 44571 non-null  int64
#  1   title              44571 non-null  object
#  2   genres             44571 non-null  object
#  3   original_language  44571 non-null  object
#  4   overview           44571 non-null  object
#  5   runtime            44571 non-null  float64
#  6   Unnamed: 0         44571 non-null  int64
#  7   crew               44571 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
resultColumnList = result.columns

# %%
resultColumnList
# Out:
# Index(['id', 'title', 'genres', 'original_language', 'overview', 'runtime',
#        'Unnamed: 0', 'crew'],
#       dtype='object')

# %%
result = result.drop(result.columns[6], axis=1)

# %%
metadata = result.copy()

# %%
metadata
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44566  439050                       Subdue
# 44567  111109          Century of Birthing
# 44568   67758                     Betrayal
# 44569  227506             Satan Triumphant
# 44570  461257                     Queerama
#
#                                                   genres original_language  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                         [{'id': 35, 'name': 'Comedy'}]                en
# ...                                                  ...               ...
# 44566  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...                fa
# 44567                      [{'id': 18, 'name': 'Drama'}]                tl
# 44568  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...                en
# 44569                                                 []                en
# 44570                                                 []                en
#
#                                                 overview  runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...     81.0
# 1      When siblings Judy and Peter discover an encha...    104.0
# 2      A family wedding reignites the ancient feud be...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...    127.0
# 4      Just when George Banks has recovered from his ...    106.0
# ...                                                  ...      ...
# 44566        Rising and falling between a man and woman.     90.0
# 44567  An artist struggles to finish his work while a...    360.0
# 44568  When one of her hits goes wrong, a professiona...     90.0
# 44569  In a small town live two brothers, one a minis...     87.0
# 44570  50 years after decriminalisation of homosexual...     75.0
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 44566  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44567  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44568  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44569  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44570  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44571 rows x 7 columns]

# %%
del result

# %%
breakpoint=0
for i in metadata['genres']:
    # if breakpoint<=3:
        i = i.replace("[{'id': ",'')
        i = i.replace(", 'name': ",'')
        i = i.replace("}, {'id': ",'')
        i = i.replace("}]",'')
        i = i.translate(str.maketrans("", "", string.digits))
        i = i.replace("''",'-')
        i = i.replace("'",'')
        
        # print(i)
        # breakpoint+=1

# %%
import string
for i in range(len(metadata['genres'])):
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("[{'id': ",'')
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace(", 'name': ",'')
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}, {'id': ",'')
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}]",'')
    metadata['genres'].loc[i] = metadata['genres'].loc[i].translate(str.maketrans("", "", string.digits))
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("''",'-')
    metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("'",'')
# Out:
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("[{'id': ",'')
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace(", 'name': ",'')
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}, {'id': ",'')
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}]",'')
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].translate(str.maketrans("", "", string.digits))
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("''",'-')
# C:\Users\Mo Kasim\AppData\Local\Temp\ipykernel_17244\2184548895.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("'",'')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 for i in range(len(metadata['genres'])):
#       3     metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("[{'id': ",'')
# ----> 4     metadata['genres'].loc[i] = metadata['genres'].loc[i].replace(", 'name': ",'')
#       5     metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}, {'id': ",'')
#       6     metadata['genres'].loc[i] = metadata['genres'].loc[i].replace("}]",'')
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:1797, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1795     self._setitem_with_indexer_split_path(indexer, value, name)
#    1796 else:
# -> 1797     self._setitem_single_block(indexer, value, name)
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:2079, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2077 # actually do the set
#    2078 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
# -> 2079 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File c:\Python310\lib\site-packages\pandas\core\series.py:1317, in Series._maybe_update_cacher(self, clear, verify_is_copy, inplace)
#    1304 # for CoW, we never want to update the parent DataFrame cache
#    1305 # if the Series changed, and always pop the cached item
#    1306 elif (
#    1307     not (
#    1308         get_option("mode.copy_on_write")
#    (...)
#    1315     # to ensure column still in dataframe
#    1316     # otherwise, either self or ref has swapped in new arrays
# -> 1317     ref._maybe_cache_changed(cacher[0], self, inplace=inplace)
#    1318 else:
#    1319     # GH#33675 we have swapped in a new array, so parent
#    1320     #  reference to self is now invalid
#    1321     ref._item_cache.pop(cacher[0], None)
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:4307, in DataFrame._maybe_cache_changed(self, item, value, inplace)
#    4303 if old._values is value._values and inplace:
#    4304     # GH#46149 avoid making unnecessary copies/block-splitting
#    4305     return
# -> 4307 self._mgr.iset(loc, arraylike, inplace=inplace)
#
# File c:\Python310\lib\site-packages\pandas\core\internals\managers.py:1245, in BlockManager.iset(self, loc, value, inplace)
#    1243 # Accessing public blknos ensures the public versions are initialized
#    1244 blknos = self.blknos[loc]
# -> 1245 blklocs = self.blklocs[loc].copy()
#    1247 unfit_mgr_locs = []
#    1248 unfit_val_locs = []
#
# KeyboardInterrupt:

# %%
metadata['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 44566    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 44567                        [{'id': 18, 'name': 'Drama'}]
# 44568    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 44569                                                   []
# 44570                                                   []
# Name: genres, Length: 44571, dtype: object

# %%
movieData = pd.read_csv("metadata.csv")

# %%
movieData.shape
# Out:
# (44571, 7)

# %%
movieData.head(3)
# Out:
#       id             title                    genres original_language  \
# 0    862         Toy Story   Animation-Comedy-Family                en
# 1   8844           Jumanji  Adventure-Fantasy-Family                en
# 2  15602  Grumpier Old Men            Romance-Comedy                en
#
#                                             overview  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...     81.0
# 1  When siblings Judy and Peter discover an encha...    104.0
# 2  A family wedding reignites the ancient feud be...    101.0
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...

# %%
movieData = movieData.reindex(['id', 'title', 'genres','DirectorName','ProducerName', 'original_language', 'overview', 'runtime', 'crew'],axis=1)

# %%
movieData
# Out:
#            id                        title                    genres  \
# 0         862                    Toy Story   Animation-Comedy-Family
# 1        8844                      Jumanji  Adventure-Fantasy-Family
# 2       15602             Grumpier Old Men            Romance-Comedy
# 3       31357            Waiting to Exhale      Comedy-Drama-Romance
# 4       11862  Father of the Bride Part II                    Comedy
# ...       ...                          ...                       ...
# 44566  439050                       Subdue              Drama-Family
# 44567  111109          Century of Birthing                     Drama
# 44568   67758                     Betrayal     Action-Drama-Thriller
# 44569  227506             Satan Triumphant                        []
# 44570  461257                     Queerama                        []
#
#        DirectorName  ProducerName original_language  \
# 0               NaN           NaN                en
# 1               NaN           NaN                en
# 2               NaN           NaN                en
# 3               NaN           NaN                en
# 4               NaN           NaN                en
# ...             ...           ...               ...
# 44566           NaN           NaN                fa
# 44567           NaN           NaN                tl
# 44568           NaN           NaN                en
# 44569           NaN           NaN                en
# 44570           NaN           NaN                en
#
#                                                 overview  runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...     81.0
# 1      When siblings Judy and Peter discover an encha...    104.0
# 2      A family wedding reignites the ancient feud be...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...    127.0
# 4      Just when George Banks has recovered from his ...    106.0
# ...                                                  ...      ...
# 44566        Rising and falling between a man and woman.     90.0
# 44567  An artist struggles to finish his work while a...    360.0
# 44568  When one of her hits goes wrong, a professiona...     90.0
# 44569  In a small town live two brothers, one a minis...     87.0
# 44570  50 years after decriminalisation of homosexual...     75.0
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 44566  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44567  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44568  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44569  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44570  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44571 rows x 9 columns]

# %%
movieData['crew']
# Out:
# 0        [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1        [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2        [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3        [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4        [{'credit_id': '52fe44959251416c75039ed7', 'de...
#                                ...
# 44566    [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44567    [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44568    [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44569    [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44570    [{'credit_id': '593e676c92514105b702e68e', 'de...
# Name: crew, Length: 44571, dtype: object

# %%
import ast

# %%
directorName=[]
breakPoint = 0
for i in movieData['crew']:
    # if breakPoint <5:
        dict_list = ast.literal_eval(i)
        # breakPoint+=1
        flag =0
        for j in range(len(dict_list)):
            if dict_list[j]['job']=="Director":
                # print(dict_list[j]['name'])
                directorName.append(dict_list[j]['name'])
                # movieData['DirectorName'].loc[i]=dict_list[j]['name']
                flag =1
                break
        if flag==0:
            directorName.append(None)

# %%
len(directorName)
# Out:
# 44571

# %%
# print(directorName)

# %%
movieData['DirectorName']=directorName

# %%
movieData
# Out:
#            id                        title                    genres  \
# 0         862                    Toy Story   Animation-Comedy-Family
# 1        8844                      Jumanji  Adventure-Fantasy-Family
# 2       15602             Grumpier Old Men            Romance-Comedy
# 3       31357            Waiting to Exhale      Comedy-Drama-Romance
# 4       11862  Father of the Bride Part II                    Comedy
# ...       ...                          ...                       ...
# 44566  439050                       Subdue              Drama-Family
# 44567  111109          Century of Birthing                     Drama
# 44568   67758                     Betrayal     Action-Drama-Thriller
# 44569  227506             Satan Triumphant                        []
# 44570  461257                     Queerama                        []
#
#            DirectorName  ProducerName original_language  \
# 0         John Lasseter           NaN                en
# 1          Joe Johnston           NaN                en
# 2         Howard Deutch           NaN                en
# 3       Forest Whitaker           NaN                en
# 4         Charles Shyer           NaN                en
# ...                 ...           ...               ...
# 44566  Hamid Nematollah           NaN                fa
# 44567          Lav Diaz           NaN                tl
# 44568    Mark L. Lester           NaN                en
# 44569  Yakov Protazanov           NaN                en
# 44570     Daisy Asquith           NaN                en
#
#                                                 overview  runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...     81.0
# 1      When siblings Judy and Peter discover an encha...    104.0
# 2      A family wedding reignites the ancient feud be...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...    127.0
# 4      Just when George Banks has recovered from his ...    106.0
# ...                                                  ...      ...
# 44566        Rising and falling between a man and woman.     90.0
# 44567  An artist struggles to finish his work while a...    360.0
# 44568  When one of her hits goes wrong, a professiona...     90.0
# 44569  In a small town live two brothers, one a minis...     87.0
# 44570  50 years after decriminalisation of homosexual...     75.0
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 44566  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44567  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44568  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44569  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44570  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44571 rows x 9 columns]

# %%
producerName = []
breakPoint = 0
for i in movieData['crew']:
    # if breakPoint <5:
        dict_list = ast.literal_eval(i)
        # breakPoint+=1
        flag = 0
        for j in range(len(dict_list)):
            if dict_list[j]['job']=="Producer":
                producerName.append(dict_list[j]['name'])
                # print(dict_list[j]['name'])
                # movieData['ProducerName'].loc[i]=dict_list[j]['name']
                flag =1
                break
        if flag ==0:
            producerName.append(None)

# %%
len(producerName)
# Out:
# 44571

# %%
movieData['ProducerName'] = producerName

# %%
movieData
# Out:
#            id                        title                    genres  \
# 0         862                    Toy Story   Animation-Comedy-Family
# 1        8844                      Jumanji  Adventure-Fantasy-Family
# 2       15602             Grumpier Old Men            Romance-Comedy
# 3       31357            Waiting to Exhale      Comedy-Drama-Romance
# 4       11862  Father of the Bride Part II                    Comedy
# ...       ...                          ...                       ...
# 44566  439050                       Subdue              Drama-Family
# 44567  111109          Century of Birthing                     Drama
# 44568   67758                     Betrayal     Action-Drama-Thriller
# 44569  227506             Satan Triumphant                        []
# 44570  461257                     Queerama                        []
#
#            DirectorName         ProducerName original_language  \
# 0         John Lasseter        Bonnie Arnold                en
# 1          Joe Johnston         Scott Kroopf                en
# 2         Howard Deutch                 None                en
# 3       Forest Whitaker          Ronald Bass                en
# 4         Charles Shyer         Nancy Meyers                en
# ...                 ...                  ...               ...
# 44566  Hamid Nematollah     Hamid Nematollah                fa
# 44567          Lav Diaz                 None                tl
# 44568    Mark L. Lester                 None                en
# 44569  Yakov Protazanov  Joseph N. Ermolieff                en
# 44570     Daisy Asquith                 None                en
#
#                                                 overview  runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...     81.0
# 1      When siblings Judy and Peter discover an encha...    104.0
# 2      A family wedding reignites the ancient feud be...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...    127.0
# 4      Just when George Banks has recovered from his ...    106.0
# ...                                                  ...      ...
# 44566        Rising and falling between a man and woman.     90.0
# 44567  An artist struggles to finish his work while a...    360.0
# 44568  When one of her hits goes wrong, a professiona...     90.0
# 44569  In a small town live two brothers, one a minis...     87.0
# 44570  50 years after decriminalisation of homosexual...     75.0
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 44566  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44567  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44568  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44569  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44570  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44571 rows x 9 columns]

# %%
movieData.drop("crew", axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 moviedata = movieData.drop("crew", axis =1)
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['crew'] not found in axis"

# %%
movieData.isna().sum()
# Out:
# id                       0
# title                    0
# genres                   0
# DirectorName           803
# ProducerName         22718
# original_language        0
# overview                 0
# runtime                  0
# crew                     0
# dtype: int64

# %%
movieData = movieData.dropna()

# %%
movieData.isna().sum()
# Out:
# id                   0
# title                0
# genres               0
# DirectorName         0
# ProducerName         0
# original_language    0
# overview             0
# runtime              0
# crew                 0
# dtype: int64

# %%
movieData.to_csv("metadata.csv", index=False)

# %%
movieData
# Out:
#                                    MovieID                    MovieName  \
# 0         862                    Toy Story      Animation-Comedy-Family
# 1        8844                      Jumanji     Adventure-Fantasy-Family
# 3       31357            Waiting to Exhale         Comedy-Drama-Romance
# 4       11862  Father of the Bride Part II                       Comedy
# 5         949                         Heat  Action-Crime-Drama-Thriller
# ...       ...                          ...                          ...
# 44562  390959    Shadow of the Blair Witch               Mystery-Horror
# 44564  222848              Caged Heat 3000              Science Fiction
# 44565   30840                   Robin Hood         Drama-Action-Romance
# 44566  439050                       Subdue                 Drama-Family
# 44569  227506             Satan Triumphant                           []
#
#            DirectorName         ProducerName Duration  \
# 0         John Lasseter        Bonnie Arnold       en
# 1          Joe Johnston         Scott Kroopf       en
# 3       Forest Whitaker          Ronald Bass       en
# 4         Charles Shyer         Nancy Meyers       en
# 5          Michael Mann           Art Linson       en
# ...                 ...                  ...      ...
# 44562          Ben Rock    Jay Bogdanowitsch       en
# 44564     Aaron Osborne           Mike Upton       en
# 44565        John Irvin      Sarah Radclyffe       en
# 44566  Hamid Nematollah     Hamid Nematollah       fa
# 44569  Yakov Protazanov  Joseph N. Ermolieff       en
#
#                                                    Story  Genre  \
# 0      Led by Woody, Andy's toys live happily in his ...   81.0
# 1      When siblings Judy and Peter discover an encha...  104.0
# 3      Cheated on, mistreated and stepped on, the wom...  127.0
# 4      Just when George Banks has recovered from his ...  106.0
# 5      Obsessive master thief, Neil McCauley leads a ...  170.0
# ...                                                  ...    ...
# 44562  In this true-crime documentary, we delve into ...   45.0
# 44564  It's the year 3000 AD. The world's most danger...   85.0
# 44565  Yet another version of the classic epic, with ...  104.0
# 44566        Rising and falling between a man and woman.   90.0
# 44569  In a small town live two brothers, one a minis...   87.0
#
#                                                 Language
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# 5      [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# ...                                                  ...
# 44562  [{'credit_id': '56ff6ddbc3a3686e9e0013bc', 'de...
# 44564  [{'credit_id': '5757f36ac3a3687d6f000e8a', 'de...
# 44565  [{'credit_id': '52fe44439251416c9100a899', 'de...
# 44566  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44569  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
#
# [21825 rows x 9 columns]

# %%
movieData.columns = ['MovieID', 'MovieName', 'Genre', 'DirectorName', 'ProducerName','Language',  'Story', 'Duration',  '']

# %%
movieData = movieData.drop(movieData.columns[8],axis=1)

# %%
movieData.to_csv("MovieMasterData.csv", index= False)

# %%
movieData = pd.read_csv("MovieMasterData.csv")

# %%
movieData
# Out:
#        MovieID                    MovieName                        Genre  \
# 0          862                    Toy Story      Animation-Comedy-Family
# 1         8844                      Jumanji     Adventure-Fantasy-Family
# 2        31357            Waiting to Exhale         Comedy-Drama-Romance
# 3        11862  Father of the Bride Part II                       Comedy
# 4          949                         Heat  Action-Crime-Drama-Thriller
# ...        ...                          ...                          ...
# 21820   390959    Shadow of the Blair Witch               Mystery-Horror
# 21821   222848              Caged Heat 3000              Science Fiction
# 21822    30840                   Robin Hood         Drama-Action-Romance
# 21823   439050                       Subdue                 Drama-Family
# 21824   227506             Satan Triumphant                           []
#
#            DirectorName         ProducerName Language  \
# 0         John Lasseter        Bonnie Arnold       en
# 1          Joe Johnston         Scott Kroopf       en
# 2       Forest Whitaker          Ronald Bass       en
# 3         Charles Shyer         Nancy Meyers       en
# 4          Michael Mann           Art Linson       en
# ...                 ...                  ...      ...
# 21820          Ben Rock    Jay Bogdanowitsch       en
# 21821     Aaron Osborne           Mike Upton       en
# 21822        John Irvin      Sarah Radclyffe       en
# 21823  Hamid Nematollah     Hamid Nematollah       fa
# 21824  Yakov Protazanov  Joseph N. Ermolieff       en
#
#                                                    Story  Duration
# 0      Led by Woody, Andy's toys live happily in his ...      81.0
# 1      When siblings Judy and Peter discover an encha...     104.0
# 2      Cheated on, mistreated and stepped on, the wom...     127.0
# 3      Just when George Banks has recovered from his ...     106.0
# 4      Obsessive master thief, Neil McCauley leads a ...     170.0
# ...                                                  ...       ...
# 21820  In this true-crime documentary, we delve into ...      45.0
# 21821  It's the year 3000 AD. The world's most danger...      85.0
# 21822  Yet another version of the classic epic, with ...     104.0
# 21823        Rising and falling between a man and woman.      90.0
# 21824  In a small town live two brothers, one a minis...      87.0
#
# [21825 rows x 8 columns]

# %%
movieData.isna().sum()
# Out:
# MovieID         0
# MovieName       0
# Genre           0
# DirectorName    0
# ProducerName    0
# Language        0
# Story           0
# Duration        0
# dtype: int64

# %%
movieData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21825 entries, 0 to 21824
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       21825 non-null  int64
#  1   MovieName     21825 non-null  object
#  2   Genre         21825 non-null  object
#  3   DirectorName  21825 non-null  object
#  4   ProducerName  21825 non-null  object
#  5   Language      21825 non-null  object
#  6   Story         21825 non-null  object
#  7   Duration      21825 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
movieData.shape
# Out:
# (21825, 8)

# %%
emptyGenres = []
for i in range(len(movieData['Genre'])):
    if movieData['Genre'].loc[i]=='[]':
        print(movieData['MovieID'].loc[i])
        # print(type(movieData['Genre'].loc[i]))
        # emptyGenres.append(movieData['MovieID'].loc[i])
        # movieData = movieData[movieData["Genre"]!='[]']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 541
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 3
#       1 emptyGenres = []
#       2 for i in range(len(movieData['Genre'])):
# ----> 3     if movieData['Genre'].loc[i]=='[]':
#       4         print(movieData['MovieID'].loc[i])
#       5         # print(type(movieData['Genre'].loc[i]))
#       6         # emptyGenres.append(movieData['MovieID'].loc[i])
#       7         # movieData = movieData[movieData["Genre"]!='[]']
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File c:\Python310\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 541

# %%
emptyGenres
# Out:
# [42758,
#  125021,
#  125124,
#  141489,
#  159727,
#  201724,
#  58098,
#  42142,
#  277724,
#  210728,
#  41660,
#  210937,
#  1777,
#  60562,
#  64022,
#  25007,
#  121043,
#  90374,
#  157373,
#  60612,
#  250093,
#  19422,
#  54191,
#  39306,
#  94466,
#  124994,
#  63771,
#  129689,
#  178736,
#  126421,
#  145217,
#  153913,
#  32638,
#  154442,
#  166671,
#  135198,
#  114444,
#  59828,
#  109887,
#  150712,
#  31324,
#  178587,
#  117401,
#  41822,
#  47273,
#  174593,
#  132122,
#  29860,
#  279159,
#  172214,
#  32327,
#  148857,
#  191600,
#  131360,
#  131671,
#  135547,
#  140668,
#  160324,
#  194668,
#  199687,
#  260156,
#  31122,
#  171738,
#  128129,
#  143534,
#  180998,
#  53061,
#  136727,
#  140873,
#  143295,
#  124295,
#  109364,
#  244838,
#  154188,
#  36132,
#  157045,
#  181876,
#  171357,
#  27739,
#  127817,
#  122348,
#  131903,
#  218582,
#  124998,
#  123620,
#  13621,
#  218098,
#  141063,
#  140032,
#  221234,
#  122479,
#  199198,
#  83140,
#  218393,
#  69974,
#  125472,
#  198772,
#  31292,
#  137960,
#  256306,
#  100205,
#  255843,
#  94236,
#  29631,
#  225982,
#  143525,
#  56177,
#  54388,
#  94809,
#  75947,
#  73369,
#  69520,
#  103216,
#  92657,
#  140883,
#  139075,
#  204912,
#  200450,
#  279086,
#  126841,
#  184681,
#  142373,
#  142374,
#  12424,
#  38313,
#  41610,
#  137984,
#  302721,
#  146778,
#  150191,
#  289679,
#  120672,
#  135679,
#  267815,
#  198204,
#  263570,
#  72785,
#  62091,
#  133560,
#  156389,
#  156388,
#  143769,
#  105529,
#  198661,
#  143602,
#  65576,
#  86279,
#  171160,
#  157174,
#  158598,
#  81551,
#  143980,
#  42693,
#  36516,
#  145203,
#  31743,
#  28536,
#  119944,
#  217919,
#  114377,
#  143169,
#  345575,
#  79426,
#  196253,
#  285959,
#  105157,
#  105153,
#  58551,
#  67560,
#  292523,
#  289673,
#  153444,
#  58396,
#  12831,
#  78827,
#  145191,
#  98642,
#  260182,
#  81389,
#  220005,
#  158942,
#  191703,
#  324340,
#  367108,
#  70151,
#  255733,
#  69427,
#  97943,
#  33827,
#  130436,
#  169726,
#  250974,
#  40534,
#  157515,
#  145244,
#  144341,
#  377150,
#  175331,
#  95700,
#  146905,
#  118430,
#  405653,
#  123858,
#  134390,
#  175587,
#  111582,
#  128669,
#  103218,
#  105693,
#  192178,
#  410455,
#  117592,
#  148753,
#  29638,
#  79871,
#  41599,
#  378435,
#  160261,
#  137669,
#  407204,
#  130450,
#  433034,
#  28670,
#  158273,
#  100185,
#  230867,
#  320453,
#  182937,
#  147939,
#  140530,
#  44124,
#  433583,
#  291577,
#  413687,
#  130980,
#  447091,
#  76059,
#  47798,
#  118144,
#  76116,
#  303835,
#  145813,
#  165023,
#  66878,
#  147871,
#  456018,
#  187602,
#  130278,
#  103462,
#  212865,
#  408624,
#  61385,
#  227506]

# %%
len(emptyGenres)
# Out:
# 253

# %%
movieData.to_csv("MovieMasterData.csv", index=False)
